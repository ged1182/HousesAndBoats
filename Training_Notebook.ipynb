# %% [markdown]
# # Training Notebook

# %%
% run CapsNet.py --h
# Out:
# usage: CapsNet.py [-h] [--dataset dataset] [--min_epochs min_epochs]
#                   [--max_epochs max_epochs]
#                   [--train_batch_size train_batch_size]
#                   [--val_batch_size val_batch_size] [--lr lr]
#                   [--patience PATIENCE] [--overfit_pct OVERFIT_PCT]
#                   [--conv_channels CONV_CHANNELS]
#                   [--nb_capsule_blocks NB_CAPSULE_BLOCKS]
#                   [--primary_caps_dim PRIMARY_CAPS_DIM]
#                   [--class_caps_dim CLASS_CAPS_DIM]
#                   [--routing_iters ROUTING_ITERS]
#                   [--reconstruction RECONSTRUCTION]
#                   [--resume_from_ckpt RESUME_FROM_CHECKPOINT] [--fc1 FC1]
#                   [--fc2 FC2] [--mse_factor MSE_FACTOR]
#
# optional arguments:
#   -h, --help            show this help message and exit
#   --dataset dataset     The dataset to use (default: HB, choices: ['MNIST',
#                         'HB', 'HB_Colored'])
# ...

# %%
# %run CapsNet.py --dataset HB --conv_channels 64 --nb_capsule_blocks 4 --reconstruction True --fc1 1024 --fc2 2048 --patience 5 --train_batch_size 64 --val_batch_size 512 --lr 3e-4 --mse_factor 9e-5
# Out:
# Namespace(class_caps_dim=16, conv_channels=64, dataset='HB', fc1=1024, fc2=2048, lr=0.0003, max_epochs=100, min_epochs=1, mse_factor=9e-05, nb_capsule_blocks=4, overfit_pct=0.0, patience=5, primary_caps_dim=8, reconstruction=True, resume_from_checkpoint='', routing_iters=3, train_batch_size=64, val_batch_size=512)
# Dataset: HB
# Training Examples:  16,385
# Validation Examples:  2,048
# Input Size: torch.Size([1, 64, 64])
# The model has 11,909,280 parameters.
# INFO:root:gpu available: True, used: True
# INFO:root:VISIBLE GPUS: 0
# GPU Found!
# INFO:root:
#                           Name         Type Params
# 0                      encoder   Sequential    1 M
# 1                    encoder.0       Conv2d    5 K
# 2                    encoder.1  PrimaryCaps  165 K
# 3     encoder.1.capsule_blocks   ModuleList  165 K
# 4   encoder.1.capsule_blocks.0       Conv2d   41 K
# 5   encoder.1.capsule_blocks.1       Conv2d   41 K
# 6   encoder.1.capsule_blocks.2       Conv2d   41 K
# ...

# %%
5e-4
# Out:
# 0.0005

# %%
1e-5
# Out:
# 1e-05

# %%
768/(64*64)* 0.0005
# Out:
# 9.375e-05

# %%
2.34e4
# Out:
# 23400.0
