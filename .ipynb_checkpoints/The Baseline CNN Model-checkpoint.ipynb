# %%
import numpy as np
import torch
from torch.nn.functional import softmax
from torch.nn import CrossEntropyLoss
from torch.optim import Adam
import os
import importlib
import utils
import time
import matplotlib.pyplot as plt
import models
data_dir ="./data"
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cpu

# %%
importlib.reload(utils)
importlib.reload(models)
# Out:
# <module 'models' from 'C:\\Users\\ged11\\Dropbox\\0 TUM\\Deep Learning Seminar\\HousesAndBoats\\models.py'>

# %%
training_data, validation_data = utils.get_train_val_data(data_dir=data_dir,verbose=True)
testing_data = utils.get_test_data(data_dir=data_dir,verbose=True)
classes = training_data.classes
# Out:
# 4 Classes: ['boat', 'house', 'rectangle', 'triangle']
# Training Size: 1000
# Validation Size: 200
# 4 Classes: ['boat', 'house', 'rectangle', 'triangle']
# Testing Size: 200

# %%
training_loader = utils.get_loader(training_data)
validation_loader = utils.get_loader(validation_data)
testing_loader = utils.get_loader(testing_data)

# %%
utils.show_images(training_loader,classes,num_imgs=8)
utils.show_images(testing_loader,classes)

# %% [markdown]
# # Baseline CNN Model

# %%
model = models.BaselineCNNModel()
model.to(device)
# Out:
# BaselineCNNModel(
#   (features): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=(2, 2), stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#     (4): ReLU()
#     (5): MaxPool2d(kernel_size=(2, 2), stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1))
#     (7): ReLU()
#     (8): MaxPool2d(kernel_size=(2, 2), stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifer): Sequential(
#     (0): Linear(in_features=25088, out_features=1024, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=1024, out_features=256, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=256, out_features=16, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=16, out_features=4, bias=True)
#   )
# )

# %%
samples, targets = next(iter(training_loader))
samples, targets = samples.to(device), targets.to(device)
score = model(samples)

# %%
loss_fn = CrossEntropyLoss()

# %%
loss_fn(score,targets)
# Out:
# tensor(1.3875, grad_fn=<NllLossBackward>)

# %%
model = models.Baseline_CNN_Model()
model.to(device)
log_every_batches = 30
log_every_epochs = 5
num_epochs = 50
train_losses = []
train_accuracies = []
val_accuracies = []
train_size = len(training_data)
val_size = len(validation_data)
val_losses = []
loss_fn = CrossEntropyLoss()
optimizer = Adam(model.parameters(),lr=3e-4)
number_of_train_batches = len(training_loader)
for epoch in range(num_epochs):
    batch_losses = []
    num_correct = 0
    model.train()
    for i, data in enumerate(training_loader,0):
        samples, targets = data
        samples, targets = samples.to(device), targets.to(device)
        optimizer.zero_grad()
        scores = model.forward(samples)
        loss = loss_fn(scores, targets)
        loss.backward()
        optimizer.step()
        batch_losses.append(loss.item())
        y = softmax(scores)
        y = torch.argmax(y,dim=1)
        num_correct += np.sum(y.cpu().numpy()==targets.cpu().numpy())
#         if (i+1) % log_every_batches ==0:
#             print("Epoch {0:d}, Batch {1:d}/{2:d}\nTraining Loss {3:.4f}".format(
#                 epoch+1,i+1,number_of_train_batches,loss.item()))
    epoch_loss = np.mean(batch_losses)
    train_losses.append(epoch_loss)
    epoch_accuracy = num_correct/train_size
    train_accuracies.append(epoch_accuracy)
    if (epoch+1) % log_every_epochs ==0:
        print("Epoch {0:d}; Training Loss {1:.4f}; Training Accuracy {2:.4f}".format(epoch+1,
                                                                                     epoch_loss,
                                                                                     epoch_accuracy))
    num_correct = 0
    model.eval()
    for i, data in enumerate(validation_loader,0):
        batch_losses = []
        
        samples, targets = data
        samples, targets = samples.to(device), targets.to(device)
        scores = model(samples)
        loss = loss_fn(scores, targets)
        batch_losses.append(loss.item())
        y = softmax(scores)
        y = torch.argmax(y,dim=1)
        num_correct += np.sum(y.cpu().numpy()==targets.cpu().numpy())
    val_loss = np.mean(batch_losses)
    val_losses.append(val_loss)
    val_accuracy = num_correct/val_size
    val_accuracies.append(val_accuracy)
    if (epoch +1) % log_every_epochs ==0:
        print("Epoch {0:d}; Validation Loss {1:.4f}; Validation Accuracy {2:.4f}".format(epoch+1,
                                                                                         val_loss,
                                                                                         val_accuracy))
# Out:
# /home/paperspace/.local/lib/python3.7/site-packages/ipykernel_launcher.py:28: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
# /home/paperspace/.local/lib/python3.7/site-packages/ipykernel_launcher.py:52: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
# Epoch 5; Training Loss 1.1487; Training Accuracy 0.4720
# Epoch 5; Validation Loss 1.1983; Validation Accuracy 0.4500
# Epoch 10; Training Loss 0.8437; Training Accuracy 0.6150
# Epoch 10; Validation Loss 1.1656; Validation Accuracy 0.6250
# Epoch 15; Training Loss 0.4630; Training Accuracy 0.8080
# Epoch 15; Validation Loss 0.9225; Validation Accuracy 0.7000
# Epoch 20; Training Loss 0.2325; Training Accuracy 0.9200
# Epoch 20; Validation Loss 0.6617; Validation Accuracy 0.7800
# Epoch 25; Training Loss 0.1342; Training Accuracy 0.9520
# Epoch 25; Validation Loss 0.8419; Validation Accuracy 0.7550
# Epoch 30; Training Loss 0.0691; Training Accuracy 0.9810
# Epoch 30; Validation Loss 0.1805; Validation Accuracy 0.7750
# Epoch 35; Training Loss 0.0434; Training Accuracy 0.9880
# Epoch 35; Validation Loss 0.4273; Validation Accuracy 0.8250
# Epoch 40; Training Loss 0.0274; Training Accuracy 0.9910
# Epoch 40; Validation Loss 0.1875; Validation Accuracy 0.8150
# Epoch 45; Training Loss 0.0201; Training Accuracy 0.9950
# Epoch 45; Validation Loss 0.1316; Validation Accuracy 0.8450
# Epoch 50; Training Loss 0.0097; Training Accuracy 0.9970
# Epoch 50; Validation Loss 2.4804; Validation Accuracy 0.8700

# %%
plt.plot(np.arange(len(train_losses)),train_losses)
plt.plot(np.arange(len(val_losses)),val_losses)
plt.show()

# %%
plt.plot(np.arange(len(train_accuracies)),train_accuracies)
plt.plot(np.arange(len(val_accuracies)),val_accuracies)
plt.show()

# %%
val_loss
# Out:
# 0.7946680784225464

# %% [markdown]
# # Capset Model

# %%
model = models.CapsuleNet()
# Out:
# self.route_weights.shape torch.Size([8, 1, 256, 32])
# self.route_weights[:,None,:,:,:].shape torch.Size([8, 1, 1, 256, 32])
# self.route_weights.shape torch.Size([4, 1152, 8, 16])
# self.route_weights[:,None,:,:,:].shape torch.Size([4, 1, 1152, 8, 16])

# %%
samples, targets = next(iter(training_loader))

# %%
samples.shape
# Out:
# torch.Size([16, 3, 128, 128])

# %%
samples[0:1].shape
# Out:
# torch.Size([1, 3, 128, 128])

# %%
model(samples[0:2
            ])
# Out:
# x[None,:,:,None].shape torch.Size([1, 2, 256, 1, 120, 120])
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-59-fbd52ea60843> in <module>
# ----> 1 model(samples[0:2
#       2             ])
#
# ~\Anaconda3\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# ~\Dropbox\0 TUM\Deep Learning Seminar\HousesAndBoats\models.py in forward(self, x, y)
#     115     def forward(self, x, y=None):
#     116         x = F.relu(self.conv1(x), inplace=True)
# --> 117         x = self.primary_capsules(x)
#     118         x = self.shape_capsules(x).squeeze().transpose(0, 1)
#     119
#
# ~\Anaconda3\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# ~\Dropbox\0 TUM\Deep Learning Seminar\HousesAndBoats\models.py in forward(self, x)
#      75             print('x[None,:,:,None].shape',x[None,:,:,None].shape)
#      76
# ---> 77             priors = x[None, :, :, None] @ self.route_weights[:, None, :, :, :]
#      78             logits = torch.zeros(*priors.size())
#      79
#
# RuntimeError: The size of tensor a (2) must match the size of tensor b (8) at non-singleton dimension 1

# %%
x = samples[0:1]
x.shape
# Out:
# torch.Size([1, 3, 128, 128])

# %%
x[None,:,:,None].shape
# Out:
# torch.Size([1, 1, 3, 1, 128, 128])

# %%
x = np.random.randn(3,3)

# %%
x
# Out:
# array([[ 0.67044053, -1.16820259,  0.26817361],
#        [-0.89666274, -1.01662429,  0.30752116],
#        [ 0.12020837,  0.67050947, -0.76119221]])

# %%
x.shape
# Out:
# (3, 3)

# %%
x[None,:,:]
# Out:
# array([[[ 0.67044053, -1.16820259,  0.26817361],
#         [-0.89666274, -1.01662429,  0.30752116],
#         [ 0.12020837,  0.67050947, -0.76119221]]])

# %%
x[None,:,:].shape
# Out:
# (1, 3, 3)

# %%
x[None,:,None]
# Out:
# array([[[[ 0.67044053, -1.16820259,  0.26817361]],
#
#         [[-0.89666274, -1.01662429,  0.30752116]],
#
#         [[ 0.12020837,  0.67050947, -0.76119221]]]])

# %%
x[:,None]
# Out:
# array([[[ 0.67044053, -1.16820259,  0.26817361]],
#
#        [[-0.89666274, -1.01662429,  0.30752116]],
#
#        [[ 0.12020837,  0.67050947, -0.76119221]]])

# %%
x[None,None,:].shape
# Out:
# (1, 1, 3, 3)
